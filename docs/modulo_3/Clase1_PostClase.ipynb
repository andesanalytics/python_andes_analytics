# %%
#Importar librería Pandas con la abreviación pd
import pandas as pd

# %%
# Para crear una Serie se usa:
S = pd.Series(['Vida', 'Auto', 'Cesantía', 'Desgravamen'], dtype = 'object')
print(S)
# Out:
# 0           Vida
# 1           Auto
# 2       Cesantía
# 3    Desgravamen
# dtype: object

# %%
# Recordar que para revisar atributos, se necesita previamente saber y usar el nombre del objeto
S.size # Tamaño del objeto
S.dtype # Tipo de Objeto
# Out:
# dtype('O')

# %%
# PREPARAR ENTORNO

# 1.- Leer un archivo desde el Sistema Local

# Importar solo files de la librería google.colab
from google.colab import files
#cargar archivo al sistema local
uploaded_file = files.upload()

# %%
# 2.- Leer el archivo de Google Drive

# importar solo drive de google.colab
from google.colab import drive
drive.mount('/content/drive')

# %%
# LEER ARCHIVO

# 1.- Leer un archivo CSV
df = pd.read_csv('/content/drive/MyDrive/siniestralidad_seguros.csv', sep = ',')

# %%
#Métodos propios para DataFrame
df.head(3) # Visualizar las primeras n filas
# Out:
#     Año Tipo de Siniestro  Cantidad  Costo Total (USD)
# 0  2020         Automóvil       120              50000
# 1  2020              Vida        80              40000
# 2  2021         Automóvil       140              55000

# %%
df.tail(3) # Visualizas las últimas n filas
# Out:
#     Año Tipo de Siniestro  Cantidad  Costo Total (USD)
# 4  2022         Automóvil       150              60000
# 5  2022              Vida        90              45000
# 6  2023         Automóvil       160              65000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Año                7 non-null      int64
#  1   Tipo de Siniestro  7 non-null      object
#  2   Cantidad           7 non-null      int64
#  3   Costo Total (USD)  7 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 352.0+ bytes

# %%
df.describe() # Proporciona estadística descriptiva del DataFrame
# Out:
#                Año    Cantidad  Costo Total (USD)
# count     7.000000    7.000000           7.000000
# mean   2021.285714  117.857143       51000.000000
# std       1.112697   33.148296        9416.297928
# min    2020.000000   80.000000       40000.000000
# 25%    2020.500000   87.500000       43500.000000
# 50%    2021.000000  120.000000       50000.000000
# 75%    2022.000000  145.000000       57500.000000
# max    2023.000000  160.000000       65000.000000

# %%
# Atributos de un dataframe
df.shape # Indica el número de filas y columnas
# Out:
# (7, 4)

# %%
df.size # Celdas del DataFrame
# Out:
# 28

# %%
df.columns #Muestra el nombre de las columnas.
# Out:
# Index(['Año', 'Tipo de Siniestro', 'Cantidad', 'Costo Total (USD)'], dtype='object')

# %%
df.dtypes #muestra los tipos de datos de las columnas
# Out:
# Año                   int64
# Tipo de Siniestro    object
# Cantidad              int64
# Costo Total (USD)     int64
# dtype: object

# %%
# Leer un archivo excel
upload_file2 = files.upload()
# Out:
#      <input type="file" id="files-e7ac3988-807c-49ef-9995-16d99cdb5f5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7ac3988-807c-49ef-9995-16d99cdb5f5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_excel('/content/Parametros Base.xlsx', sheet_name = 'Coberturas')

# %%
df1.head()
# Out:
#    KEY_3                NOMBRE COBERTURA
# 0     27  Reembolso Gastos Catastroficos
# 1     29    Asistencia Medica Extranjero
# 2     30   Urgencia Beneficiario Titular
# 3     31     Urgencia Beneficiario Carga
# 4     28    Reembolso Gastos Oncologicos
